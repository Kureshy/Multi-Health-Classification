# %% [markdown]
# # About the dataset
#
# The aim of the model of this notebook is to create a heart failure predictor, the dataset used is an amalgamation of five different datasets that have a conjunction on eleven different features.
#
# # Attributes
# - Age: age of the patient [years]
# - Sex: sex of the patient [M: Male, F: Female]
# - ChestPainType: chest pain type [TA: Typical Angina, ATA:   Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# - RestingBP: resting blood pressure [mm Hg]
# - Cholesterol: serum cholesterol [mm/dl]
# - FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# - RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# - MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# - ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# - Oldpeak: oldpeak = ST [Numeric value measured in depression]
# - ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# - HeartDisease: output class [1: heart disease, 0: Normal]

# %%
# A simple dictionary for looking up attributes
attribute_lookup={'Age': 'age of the patient [years]','Sex': 'sex of the patient [M: Male, F: Female]',
'ChestPainType': 'chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]',
'RestingBP': 'resting blood pressure [mm Hg]',
'Cholesterol': 'serum cholesterol [mm/dl]',
'FastingBS': 'fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]',
'RestingECG': 'resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes criteria]',
'MaxHR': 'maximum heart rate achieved [Numeric value between 60 and 202]',
'ExerciseAngina':'exercise-induced angina [Y: Yes, N: No]',
'Oldpeak': 'oldpeak = ST [Numeric value measured in depression]',
'ST_Slope': 'the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]',
'HeartDisease': 'output class [1: heart disease, 0: Normal]'}

# %%
attribute_lookup['Age']
# Out:
# 'age of the patient [years]'

# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Creating a dataframe
data=pd.read_csv('heart.csv')

# %%
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
#Shape of the data
data.shape
# Out:
# (918, 12)

# %%
dataframe=pd.DataFrame(data,index=None)

# %%
dataframe.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
dataframe[['Age','Sex','HeartDisease']]
# Out:
#      Age Sex  HeartDisease
# 0     40   M             0
# 1     49   F             1
# 2     37   M             0
# 3     48   F             1
# 4     54   M             0
# ..   ...  ..           ...
# 913   45   M             1
# 914   68   M             1
# 915   57   M             1
# 916   57   F             1
# 917   38   M             0
#
# [918 rows x 3 columns]

# %% [markdown]
# **Observing the Heart disease prevalence with respect to age**

# %%
plt.figure(figsize=(15,10))
sns.countplot(dataframe['Age'],hue=dataframe['HeartDisease'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# **Exploring attributes**

# %%
print(attribute_lookup['ST_Slope'])
dataframe['ST_Slope'].unique()
# Out:
# the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# array(['Up', 'Flat', 'Down'], dtype=object)

# %%
print(attribute_lookup['ExerciseAngina'])
dataframe['ExerciseAngina'].unique()
# Out:
# exercise-induced angina [Y: Yes, N: No]
# array(['N', 'Y'], dtype=object)

# %%
print(attribute_lookup['RestingECG'])
dataframe['RestingECG'].unique()
# Out:
# resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes criteria]
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
print(attribute_lookup['ChestPainType'])
dataframe['ChestPainType'].unique()
# Out:
# chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
dataframe[['ChestPainType','HeartDisease']]
# Out:
#     ChestPainType  HeartDisease
# 0             ATA             0
# 1             NAP             1
# 2             ATA             0
# 3             ASY             1
# 4             NAP             0
# ..            ...           ...
# 913            TA             1
# 914           ASY             1
# 915           ASY             1
# 916           ATA             1
# 917           NAP             0
#
# [918 rows x 2 columns]

# %%
dataframe['ChestPainType']=dataframe['ChestPainType'].replace(['TA'],1)

# %%
dataframe['ChestPainType']=dataframe['ChestPainType'].replace(['ASY'],0)
dataframe['ChestPainType']=dataframe['ChestPainType'].replace(['ATA'],2)
dataframe['ChestPainType']=dataframe['ChestPainType'].replace(['NAP'],3)

# %%
chest_pain_types={'ASY':0,'TA':1,'ATA':2,'NAP':3}

# %%
dataframe
# Out:
#      Age Sex  ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M              2        140          289          0     Normal
# 1     49   F              3        160          180          0     Normal
# 2     37   M              2        130          283          0         ST
# 3     48   F              0        138          214          0     Normal
# 4     54   M              3        150          195          0     Normal
# ..   ...  ..            ...        ...          ...        ...        ...
# 913   45   M              1        110          264          0     Normal
# 914   68   M              0        144          193          1     Normal
# 915   57   M              0        130          131          0     Normal
# 916   57   F              2        130          236          0        LVH
# 917   38   M              3        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
dataframe['ExerciseAngina']=dataframe['ExerciseAngina'].replace(['Y'],1)
dataframe['ExerciseAngina']=dataframe['ExerciseAngina'].replace(['N'],0)

# %%
dataframe
# Out:
#      Age Sex  ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M              2        140          289          0     Normal
# 1     49   F              3        160          180          0     Normal
# 2     37   M              2        130          283          0         ST
# 3     48   F              0        138          214          0     Normal
# 4     54   M              3        150          195          0     Normal
# ..   ...  ..            ...        ...          ...        ...        ...
# 913   45   M              1        110          264          0     Normal
# 914   68   M              0        144          193          1     Normal
# 915   57   M              0        130          131          0     Normal
# 916   57   F              2        130          236          0        LVH
# 917   38   M              3        138          175          0     Normal
#
#      MaxHR  ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
dataframe['Sex']=dataframe['Sex'].replace(['M'],1)
dataframe['Sex']=dataframe['Sex'].replace(['F'],0)

# %%
gender_dict={'F':0,'M':1}

# %%
print(attribute_lookup['RestingECG'])
dataframe['RestingECG'].unique()
# Out:
# resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes criteria]
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
dataframe['RestingECG']=dataframe['RestingECG'].replace(['Normal'],-1)
dataframe['RestingECG']=dataframe['RestingECG'].replace(['ST'],0)
dataframe['RestingECG']=dataframe['RestingECG'].replace(['LVH'],1)

# %%
dataframe
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              2        140          289          0          -1
# 1     49    0              3        160          180          0          -1
# 2     37    1              2        130          283          0           0
# 3     48    0              0        138          214          0          -1
# 4     54    1              3        150          195          0          -1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              1        110          264          0          -1
# 914   68    1              0        144          193          1          -1
# 915   57    1              0        130          131          0          -1
# 916   57    0              2        130          236          0           1
# 917   38    1              3        138          175          0          -1
#
# ...

# %%
attribute_lookup['ST_Slope']
# Out:
# 'the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]'

# %%
dataframe['ST_Slope']=dataframe['ST_Slope'].replace(['Up'],1)
dataframe['ST_Slope']=dataframe['ST_Slope'].replace(['Flat'],0)
dataframe['ST_Slope']=dataframe['ST_Slope'].replace(['Down'],-1)

# %%
dataframe
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              2        140          289          0          -1
# 1     49    0              3        160          180          0          -1
# 2     37    1              2        130          283          0           0
# 3     48    0              0        138          214          0          -1
# 4     54    1              3        150          195          0          -1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              1        110          264          0          -1
# 914   68    1              0        144          193          1          -1
# 915   57    1              0        130          131          0          -1
# 916   57    0              2        130          236          0           1
# 917   38    1              3        138          175          0          -1
#
# ...

# %%
plt.figure(figsize=(10,12))
sns.heatmap(dataframe.corr(),annot=True)

# %%
dataframe.corr()
# Out:
#                      Age       Sex  ChestPainType  RestingBP  Cholesterol  \
# Age             1.000000  0.055750      -0.140307   0.254399    -0.095282
# Sex             0.055750  1.000000      -0.165747   0.005133    -0.200092
# ChestPainType  -0.140307 -0.165747       1.000000  -0.060541     0.089663
# RestingBP       0.254399  0.005133      -0.060541   1.000000     0.100893
# Cholesterol    -0.095282 -0.200092       0.089663   0.100893     1.000000
# FastingBS       0.198039  0.120076      -0.120688   0.070193    -0.260974
# RestingECG      0.213152 -0.018343      -0.039589   0.097661     0.112095
# MaxHR          -0.382045 -0.189186       0.306123  -0.112135     0.235792
# ExerciseAngina  0.215793  0.190664      -0.370652   0.155101    -0.034166
# Oldpeak         0.258612  0.105734      -0.260650   0.164803     0.050148
# ST_Slope       -0.268264 -0.150693       0.296157  -0.075162     0.111471
# HeartDisease    0.282039  0.305445      -0.466847   0.107589    -0.232741
#
# ...

# %%
sns.distplot(dataframe['Age'],kde=False,color='red',bins=25,)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x=dataframe['HeartDisease'],data=dataframe,hue='Sex')
print(gender_dict)
# Out:
# {'F': 0, 'M': 1}

# %%
sns.pairplot(data=dataframe)

# %%
X=dataframe.iloc[:,:-1]

# %%
X=np.array(X)

# %%
X
# Out:
# array([[40. ,  1. ,  2. , ...,  0. ,  0. ,  1. ],
#        [49. ,  0. ,  3. , ...,  0. ,  1. ,  0. ],
#        [37. ,  1. ,  2. , ...,  0. ,  0. ,  1. ],
#        ...,
#        [57. ,  1. ,  0. , ...,  1. ,  1.2,  0. ],
#        [57. ,  0. ,  2. , ...,  0. ,  0. ,  0. ],
#        [38. ,  1. ,  3. , ...,  0. ,  0. ,  1. ]])

# %%
y=dataframe.iloc[:,-1:]

# %%
y=np.array(dataframe['HeartDisease'])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,shuffle=True)

# %%
X_train.shape
# Out:
# (734, 11)

# %%
X_test.shape
# Out:
# (184, 11)

# %%
y_test.shape
# Out:
# (184,)

# %%
y_train.shape
# Out:
# (734,)

# %%
from tensorflow.keras import Sequential
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %%
from tensorflow.keras.layers import Dense,Flatten,InputLayer

# %%
model=Sequential()
model.add(InputLayer(input_shape=(11,)))
model.add(Dense(10,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=30,validation_data=(X_test,y_test))
# Out:
# Epoch 1/30
# 23/23 [==============================] - 1s 12ms/step - loss: 2.5118 - accuracy: 0.4496 - val_loss: 1.2829 - val_accuracy: 0.5217
# Epoch 2/30
# 23/23 [==============================] - 0s 5ms/step - loss: 1.1662 - accuracy: 0.4959 - val_loss: 1.0153 - val_accuracy: 0.5435
# Epoch 3/30
# 23/23 [==============================] - 0s 4ms/step - loss: 0.9309 - accuracy: 0.5381 - val_loss: 0.9193 - val_accuracy: 0.5815
# Epoch 4/30
# 23/23 [==============================] - 0s 4ms/step - loss: 0.8528 - accuracy: 0.5627 - val_loss: 0.9175 - val_accuracy: 0.6304
# Epoch 5/30
# 23/23 [==============================] - 0s 5ms/step - loss: 0.7480 - accuracy: 0.6158 - val_loss: 0.7388 - val_accuracy: 0.6902
# Epoch 6/30
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6281 - accuracy: 0.7071 - val_loss: 0.6802 - val_accuracy: 0.7228
# Epoch 7/30
# ...

# %%
loss=model.history.history['loss']
val_loss=model.history.history['val_loss']

# %%
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['loss', 'val_loss'], loc='upper right')

# %%
plt.plot(model.history.history['accuracy'])
plt.plot(model.history.history['val_accuracy'])
plt.legend(['accuarcy','val_accuracy'])

# %%
model.
# Out:
# 6/6 [==============================] - 0s 2ms/step
# array([[ 8.44945386e-02],
#        [ 9.20341611e-01],
#        [ 9.10667717e-01],
#        [ 6.07675835e-02],
#        [ 1.90712158e-02],
#        [-6.60621300e-02],
#        [ 7.56314754e-01],
#        [-1.78476330e-02],
#        [ 5.93463480e-01],
#        [ 7.83460200e-01],
#        [ 8.62175405e-01],
#        [-4.66257408e-02],
#        [ 6.70657098e-01],
#        [ 1.54138878e-01],
#        [ 1.35688603e-01],
#        [ 7.36963987e-01],
#        [ 8.97895217e-01],
#        [ 7.08130956e-01],
#        [ 1.84006289e-01],
#        [ 4.73454222e-02],
#        [ 2.61442721e-01],
#        [-9.38995741e-03],
#        [ 2.20153287e-01],
#        [ 4.54136431e-01],
#        [ 1.09516430e+00],
#        [ 3.07167381e-01],
#        [ 1.98885743e-02],
#        [ 7.21906304e-01],
#        [ 3.79928529e-01],
#        [ 1.41294092e-01],
#        [ 5.95170930e-02],
#        [ 3.15362304e-01],
#        [ 5.95418289e-02],
# ...
